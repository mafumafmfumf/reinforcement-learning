# %% [markdown]
# 1.
# ### 收获：
# 1）一些小细节：
# tensor.mm()矩阵乘法
# .view()创建数据视图共享数据
# .resize() in-place operation修改原tensor
# .reshape()数据视窗或复制
# shape(64,) 一维张量，不能做除法
# import torch.nn.functional as F： 不需要实例化无参数直接调用激活函数
# 自定义神经网络的初始化参数：model.fc1.bias.data.fill_(0)  model.fc1.weight.data.normal_(std=0.01)
